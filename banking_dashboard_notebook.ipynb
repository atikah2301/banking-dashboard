# %% [markdown]
# # Banking Dashboard Notebook

# %% [markdown]
# ## Test `flask`

# %%
from flask import Flask

# %%
app = Flask(__name__)

# %%
@app.route('/hello')
def hello():
    return 'Hello World'

# %%
app.run(host='localhost', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [23/Jan/2023 20:24:24] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [23/Jan/2023 20:24:25] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [23/Jan/2023 20:24:39] "GET /hello HTTP/1.1" 200 -

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import plotly.express as px

import dash
import dash_core_components as dcc
import dash_html_components as html

import glob

# %% [markdown]
# ## Load data

# %%
## Use glob to get all the file names with a certain prefix as a list of strings
## and select only the first to load file as a dataframe
filename_monzo = glob.glob("MonzoDataExport*.csv")[0]
df_monzo_full = pd.read_csv(filename_monzo)
display(df_monzo_full.tail())
# Out:
#                 Transaction ID        Date      Time          Type  \
# 861  tx_0000ARoIqb5OoPlbsQ83dZ  19/01/2023  19:16:15  Card payment
# 862  tx_0000ARoJ2AiAhM35ecsFcb  19/01/2023  19:18:21  Card payment
# 863  tx_0000ARoJ2RazvHPa1IeGIb  19/01/2023  19:18:24  Card payment
# 864  tx_0000ARoJ5oMLkC81srljGL  19/01/2023  19:19:00  Card payment
# 865  tx_0000ARs0VoqlQDX5eCC8BN  21/01/2023  14:09:39  Card payment
#
#                      Name Emoji       Category  Amount Currency  Local amount  \
# 861  Transport for London     🚆      Transport     0.0      GBP           0.0
# 862                Google     💻  Entertainment     0.0      GBP           0.0
# 863  Transport for London     🚆      Transport     0.0      GBP           0.0
# 864  Transport for London     🚆      Transport   -40.0      GBP         -40.0
# 865  Transport for London     🚆      Transport    -5.8      GBP          -5.8
#
#     Local currency                     Notes and #tags             Address  \
# ...

# %% [markdown]
# ## Plots

# %%
## Plot the scatterplot using Plotly.
fig = px.scatter(df_monzo_full, x='Date', y='Money In')
# fig.update_traces(mode='markers+lines')
fig.show()
# Out:
# <div>                            <div id="a14a934c-cd55-4f5f-80c8-5fdcd4b0c991" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a14a934c-cd55-4f5f-80c8-5fdcd4b0c991")) {                    Plotly.newPlot(                        "a14a934c-cd55-4f5f-80c8-5fdcd4b0c991",                        [{"hovertemplate":"Date=%{x}<br>Money In=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["29/01/2020","03/02/2020","03/02/2020","05/02/2020","05/02/2020","07/02/2020","08/02/2020","08/02/2020","08/02/2020","08/02/2020","08/02/2020","08/02/2020","10/02/2020","11/02/2020","11/02/2020","12/02/2020","12/02/2020","12/02/2020","12/02/2020","13/02/2020","13/02/2020",
# ...
